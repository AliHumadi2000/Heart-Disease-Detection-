# %%
#import pandas ,numpy ,seaborn and matplotlib libraries

# %%
import pandas as pd 
import numpy  as np
import seaborn as sns
import matplotlib as plt

# %% [markdown]
# # Loading data

# %%
df=pd.read_csv("https://raw.githubusercontent.com/AliHumadi2000/Heart-Disease-Detection-/main/heart.csv")

# %%
#showing first 10 records
df.head(10)

# %%
#last 10 records
df.iloc[-11:-1]# or df.tail(10)

# %% [markdown]
# # explore the type and names of varaiables
# ![image.png](attachment:image.png)

# %%
df.dtypes

# %% [markdown]
# # Calculate the recoreds that you have in the dataset

# %%
[row,column]=df.shape
print("number of rows are : ",row)
print("number of columns are ",column)

# %% [markdown]
# # doing some statical calculation (descriptive statistics)

# %%
df.describe()

# %%
#concise summary of the heart dataset like datatype ,checking if thereis null value ,count and memory usage

# %%
df.info()

# %%
#centeral tedency 
df.median()

# %%
df.mode()

# %% [markdown]
# # Checking if there is no missing value

# %%
df.count()

# %%
df.nunique()

# %%
#calculate how many male and females we have in the datset
df['sex'].value_counts()

# %%
#group the gender , age ,high blood pressure, high cholesterol and diabetes and caculate the mean 
df_group=df.groupby(['sex','age','trestbps','fbs','chol']).mean()
print(df_group)

# %% [markdown]
# # we can not drop any colulmns here cause all of them are necessary

# %%
#make sure again if there is no null value
df.isnull().sum()

# %% [markdown]
# # #now our data is clean and we have explored it
#
# # #moving to visulization part to make our data more understandable and readable

# %%
# explor how many recors ara positive and negative 
df['target'].value_counts()

# %% [markdown]
# # we see there is 165 have heart disease and 138 have not

# %%
#plot target attribute 
import matplotlib.pyplot as plt
sns.countplot(x="target", data=df)
plt.show()

# %%
#count the gender that we have in the dataset
df['sex'].value_counts()

# %%
#we have 207 male and 96 female 
#plot the gender 
sns.countplot(x='sex',data=df)
plt.show()

# %%
#show the precentage 
countFemale= len(df[df.sex == 0])
countMale = len(df[df.sex == 1])
print("Percentage of Female Patients: {:.2f}%".format((countFemale / (len(df.sex))*100)))
print("Percentage of Male Patients: {:.2f}%".format((countMale / (len(df.sex))*100)))

# %%
df.groupby('target').mean()

# %%
#bar chart that show the frequency of heart disease for age 
pd.crosstab(df.age,df.target).plot(kind="bar",figsize=(20,6))
plt.title('Heart Disease Frequency for Ages')
plt.show()

# %%
#bar chart that show the frequency of heart disease for gender
pd.crosstab(df.sex,df.target).plot(kind="bar",figsize=(15,6))
plt.title('Heart Disease Frequency for Sex')
plt.xlabel('Sex (0 = Female, 1 = Male)')
plt.xticks(rotation=0)
plt.legend(["Haven't Disease", "Have Disease"])
plt.ylabel('Frequency')
plt.show()

# %%
#now we'll plot a scatter plot to see the relation between whom has heart disease or not according max heart rate 
plt.scatter(x=df.age[df.target==1], y=df.thalach[(df.target==1)], c="red")
plt.scatter(x=df.age[df.target==0], y=df.thalach[(df.target==0)])
plt.legend(["Disease", "Not Disease"])
plt.xlabel("Age")
plt.ylabel("Maximum Heart Rate")
plt.show()

# %%
#here well see the heart disease increase according to The Slope of The Peak Exercise ST Segment  
pd.crosstab(df.slope,df.target).plot(kind="bar",figsize=(15,6))
plt.title('Heart Disease Frequency for Slope')
plt.xlabel('The Slope of The Peak Exercise ST Segment ')
plt.xticks(rotation = 0)
plt.ylabel('Frequency')
plt.show()

# %%
#here we'll see the heart disease according to The fasting blood sugar  
pd.crosstab(df.fbs,df.target).plot(kind="bar",figsize=(15,6))
plt.title('Heart Disease Frequency for fasting blood sugar')
plt.xlabel('fasting blood sugar')
plt.xticks(rotation = 0)
plt.ylabel('Frequency')
plt.show()

# %%
#here we'll see the heart disease according to The chest pain
pd.crosstab(df.cp,df.target).plot(kind="bar",figsize=(15,6))
plt.title('Heart Disease Frequency According To Chest Pain Type')
plt.xlabel('Chest Pain Type')
plt.xticks(rotation = 0)
plt.ylabel('Frequency of Disease or Not')
plt.show()
